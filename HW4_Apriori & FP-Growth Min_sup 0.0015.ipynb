# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn import datasets
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from apyori import apriori as asp_apr

# %%
df1 = pd.read_excel("Trade dataset_Pre Over.xlsx",header = None)
df1
# Out:
#                       0                   1                   2    \
# 0      BX80646I54460SR1QK  BX80662I36100SR2HG  BX80662I56400SR2L7
# 1           PBSS4350T,215       PMBT2222A,215                 NaN
# 2              BAT54A,215          BAT54C,215           BAV99,215
# 3              BAT54A,215          BAT54C,215        NX7002AK,215
# 4         74AHC1G08GV,125        74HC125D,653      74LVC125AD,118
# ...                   ...                 ...                 ...
# 36493             LM193DR                 NaN                 NaN
# 36494      1SS357(TPH3,F)                 NaN                 NaN
# 36495      1SS357(TPH3,F)                 NaN                 NaN
# 36496     JS28F512M29EWHA                 NaN                 NaN
# 36497    T6TD3XB-0003(LO)                 NaN                 NaN
#
#                       3                   4                5    \
# 0      BX80662I56500SR2L6  BX80662I76700SR2L2   X79A-GD45-PLUS
# 1                     NaN                 NaN              NaN
# 2            NX7002AK,215        PMBS3904,215     PMBS3906,215
# 3            PMBS3904,215        PMBS3906,215  PTVS5V0S1UR,115
# 4          PMEG4050EP,115                 NaN              NaN
# ...                   ...                 ...              ...
# 36493                 NaN                 NaN              NaN
# 36494                 NaN                 NaN              NaN
# 36495                 NaN                 NaN              NaN
# 36496                 NaN                 NaN              NaN
# 36497                 NaN                 NaN              NaN
#
#                    6    7    8    9    ...  241  242  243  244  245  246  247  \
# 0      Z170A GAMING M5  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      PTVS5V0S1UR,115  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 36493              NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36494              NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36495              NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36496              NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36497              NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        248  249  250
# 0      NaN  NaN  NaN
# 1      NaN  NaN  NaN
# 2      NaN  NaN  NaN
# 3      NaN  NaN  NaN
# 4      NaN  NaN  NaN
# ...    ...  ...  ...
# 36493  NaN  NaN  NaN
# 36494  NaN  NaN  NaN
# 36495  NaN  NaN  NaN
# 36496  NaN  NaN  NaN
# 36497  NaN  NaN  NaN
#
# [36498 rows x 251 columns]

# %%
records = []
for i in range(0,36498):
    records.append([str(df1.values[i,j]) for j in range(0,251)])

# %%
te = TransactionEncoder()
te_ary  = te.fit(records).transform(records)
te_ary
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df = pd.DataFrame(te_ary, columns = te.columns_)
df = df.drop(labels=['nan'],axis=1)
df
# Out:
#        01000054Z  01000056Z  01000057Z  01220088Z  01220090Z  01250003H  \
# 0          False      False      False      False      False      False
# 1          False      False      False      False      False      False
# 2          False      False      False      False      False      False
# 3          False      False      False      False      False      False
# 4          False      False      False      False      False      False
# ...          ...        ...        ...        ...        ...        ...
# 36493      False      False      False      False      False      False
# 36494      False      False      False      False      False      False
# 36495      False      False      False      False      False      False
# 36496      False      False      False      False      False      False
# 36497      False      False      False      False      False      False
#
#        01500274Z  01500322H  01520903TXN  0154004.DR  ...  ZLUSBEVAL3Z  \
# 0          False      False        False       False  ...        False
# 1          False      False        False       False  ...        False
# 2          False      False        False       False  ...        False
# 3          False      False        False       False  ...        False
# 4          False      False        False       False  ...        False
# ...          ...        ...          ...         ...  ...          ...
# 36493      False      False        False       False  ...        False
# 36494      False      False        False       False  ...        False
# 36495      False      False        False       False  ...        False
# 36496      False      False        False       False  ...        False
# 36497      False      False        False       False  ...        False
#
#        ZM4746A-GS18  ZM4747A-GS08  ZM4749A-GS08  擎網傳奇-凌風  擎網傳奇-凌風-R  擎網傳奇-煉獄  \
# 0             False         False         False    False      False    False
# 1             False         False         False    False      False    False
# 2             False         False         False    False      False    False
# 3             False         False         False    False      False    False
# 4             False         False         False    False      False    False
# ...             ...           ...           ...      ...        ...      ...
# 36493         False         False         False    False      False    False
# 36494         False         False         False    False      False    False
# 36495         False         False         False    False      False    False
# 36496         False         False         False    False      False    False
# 36497         False         False         False    False      False    False
#
#        擎網傳奇-破魂  擎網傳奇-破魂-R  賽克 零度C400
# 0        False      False      False
# 1        False      False      False
# 2        False      False      False
# 3        False      False      False
# 4        False      False      False
# ...        ...        ...        ...
# 36493    False      False      False
# 36494    False      False      False
# 36495    False      False      False
# 36496    False      False      False
# 36497    False      False      False
#
# [36498 rows x 23710 columns]

# %% [markdown]
# ## Apriori

# %%
start_apr = time.time()
frequent_itemsets_apr = apriori(df, min_support = 0.0015, use_colnames = True, low_memory= True)
frequent_itemsets_apr
# Out:
#       support                                   itemsets
# 0    0.003151                               (2N7002,215)
# 1    0.002274                             (2N7002BK,215)
# 2    0.002055                           (2N7002K-T1-GE3)
# 3    0.003534                               (2N7002LT1G)
# 4    0.002411                          (74LVC1G08GW,125)
# ..        ...                                        ...
# 101  0.002055                     (BAV70,215, BAV99,215)
# 102  0.001562                     (BAW56,215, BAV99,215)
# 103  0.001534  (BX80662I76700SR2L2, BX80662I76700KSR2L0)
# 104  0.001562                        (SC6531DA, HS8292U)
# 105  0.001617               (PMBT3904,215, PMBT3906,215)
#
# [106 rows x 2 columns]

# %%
frequent_itemsets_apr.sort_values(by= "support", ascending= False).head(20)
# Out:
#      support               itemsets
# 19  0.008137            (BAV99,215)
# 42  0.007891   (BX80662I76700SR2L2)
# 64  0.006000         (MMBT3904LT1G)
# 36  0.005644   (BX80662I56400SR2L7)
# 26  0.005315    (BX80646G3240SR1K6)
# 78  0.005206         (PMBT3904,215)
# 35  0.005151   (BX80662I36100SR2HG)
# 14  0.004822           (BAT54C,215)
# 16  0.004740           (BAT54S,215)
# 7   0.004576           (BAS316,115)
# 76  0.004576        (PMBT2222A,215)
# 41  0.004302  (BX80662I76700KSR2L0)
# 68  0.003644         (NX7002AK,215)
# 74  0.003617         (PMBS3904,215)
# 56  0.003534      (LG-19M38A-B.ATR)
# 18  0.003534            (BAV70,215)
# 3   0.003534           (2N7002LT1G)
# 12  0.003397           (BAT54A,215)
# 62  0.003370        (MMBT2222ALT1G)
# 38  0.003315   (BX80662I56500SR2L6)

# %%
rules_apr = association_rules(frequent_itemsets_apr, metric = "confidence", min_threshold = 0.8)
end_apr = time.time()
rules_apr
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0  (SC6531DA)   (HS8292U)            0.001562            0.001781  0.001562
# 1   (HS8292U)  (SC6531DA)            0.001781            0.001562  0.001562
#
#    confidence        lift  leverage  conviction
# 0    1.000000  561.507692  0.001559         inf
# 1    0.876923  561.507692  0.001559    8.112311

# %%
def arl_recommender(rules_df, product_id, recommendation_number=1):
    recommendation_list_apr = []
    sorted_rules_apr = rules_apr.sort_values("lift", ascending=False)
    for idx, product in enumerate(sorted_rules_apr["antecedents"]):
        for j in list(product):
            if j == product_id:
              recommendation_list_apr.append(list(sorted_rules_apr.iloc[idx]["consequents"])[0])
    return set(recommendation_list_apr[:recommendation_number])

# %%
arl_recommender(rules_apr, "SC6531DA", 30)
# Out:
# {'HS8292U'}

# %% [markdown]
# ## FP Growth

# %%
fpgrowth(df, min_support = 0.0015)
# Out:
#       support       itemsets
# 0    0.007891         (6689)
# 1    0.005644         (6682)
# 2    0.005151         (6679)
# 3    0.003315         (6685)
# 4    0.002685         (6646)
# ..        ...            ...
# 101  0.001562   (6049, 6041)
# 102  0.002055   (6041, 6026)
# 103  0.001699   (6041, 5983)
# 104  0.001562  (9933, 16877)
# 105  0.001534   (6688, 6689)
#
# [106 rows x 2 columns]

# %%
start_fp = time.time()
frequent_itemsets_fp = fpgrowth(df, min_support = 0.0015, use_colnames = True)
frequent_itemsets_fp
# Out:
#       support                                   itemsets
# 0    0.007891                       (BX80662I76700SR2L2)
# 1    0.005644                       (BX80662I56400SR2L7)
# 2    0.005151                       (BX80662I36100SR2HG)
# 3    0.003315                       (BX80662I56500SR2L6)
# 4    0.002685                       (BX80646I54460SR1QK)
# ..        ...                                        ...
# 101  0.001562                     (BAW56,215, BAV99,215)
# 102  0.002055                     (BAV70,215, BAV99,215)
# 103  0.001699                    (BAT54S,215, BAV99,215)
# 104  0.001562                        (SC6531DA, HS8292U)
# 105  0.001534  (BX80662I76700SR2L2, BX80662I76700KSR2L0)
#
# [106 rows x 2 columns]

# %%
frequent_itemsets_fp.sort_values(by= "support", ascending= False).head(20)
# Out:
#      support               itemsets
# 6   0.008137            (BAV99,215)
# 0   0.007891   (BX80662I76700SR2L2)
# 26  0.006000         (MMBT3904LT1G)
# 1   0.005644   (BX80662I56400SR2L7)
# 88  0.005315    (BX80646G3240SR1K6)
# 14  0.005206         (PMBT3904,215)
# 2   0.005151   (BX80662I36100SR2HG)
# 7   0.004822           (BAT54C,215)
# 54  0.004740           (BAT54S,215)
# 20  0.004576           (BAS316,115)
# 5   0.004576        (PMBT2222A,215)
# 73  0.004302  (BX80662I76700KSR2L0)
# 8   0.003644         (NX7002AK,215)
# 9   0.003617         (PMBS3904,215)
# 82  0.003534      (LG-19M38A-B.ATR)
# 39  0.003534            (BAV70,215)
# 25  0.003534           (2N7002LT1G)
# 10  0.003397           (BAT54A,215)
# 44  0.003370        (MMBT2222ALT1G)
# 3   0.003315   (BX80662I56500SR2L6)

# %%
rules_fp = association_rules(frequent_itemsets_fp, metric = "confidence", min_threshold = 0.8)
end_fp = time.time()
rules_fp
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0  (SC6531DA)   (HS8292U)            0.001562            0.001781  0.001562
# 1   (HS8292U)  (SC6531DA)            0.001781            0.001562  0.001562
#
#    confidence        lift  leverage  conviction
# 0    1.000000  561.507692  0.001559         inf
# 1    0.876923  561.507692  0.001559    8.112311

# %%
def arl_recommender_fp(rules_df, product_id, recommendation_number=1):
    recommendation_list_fp = []
    sorted_rules_fp = rules_fp.sort_values("lift", ascending=False)
    for idx, product in enumerate(sorted_rules_fp["antecedents"]):
        for j in list(product):
            if j == product_id:
              recommendation_list_fp.append(list(sorted_rules_fp.iloc[idx]["consequents"])[0])
    return set(recommendation_list_fp[:recommendation_number])

# %%
arl_recommender_fp(rules_fp, "HS8292U", 30)
# Out:
# {'SC6531DA'}

# %%
print("Apriori 所花費時間:", end_apr - start_apr)
print("FP-Growth 所花費時間:", end_fp - start_fp)
# Out:
# Apriori 所花費時間: 0.6754007339477539
# FP-Growth 所花費時間: 0.7309751510620117
